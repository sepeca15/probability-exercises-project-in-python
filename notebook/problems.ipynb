# %% [markdown]
# # Probability exercises

# %% [markdown]
# ### Exercise 1
#
# Two unbiased dice are thrown once and the total score is observed. Use a simulation to find the estimated probability that the total score is even or greater than 7
#
# We could use a mathematical equation to solve this or we can run the experiment many times, and then count the number of times where the score is even or greater than 7
#
# -Run the experiment 1000 times (roll 2 dice 1000 times, and sum the result)
#
# -Keep track of the number of times that the sum was either greater than 7 or an even number
#
# -Divide the number from step 2 by the number of iterations (1000)

# %%
#import libraries
import numpy as np
import pandas as pd

#Funtion to roll the dice. 
x = np.random.randint(7)
x
np.random.randint(7) + np.random.randint(7)

rollDice = [np.random.randint(7)+np.random.randint(7) for x in range(1000)]
greaterThanSevenOrEven = [twoDice for twoDice in rollDice if twoDice%2==0 or twoDice>7]
length = len(greaterThanSevenOrEven)
stepTwo = length -1
stepThree = stepTwo / 1000
string = 'The probability of rolling an even number or greater than 7 is:'
probability = np.round(stepThree*100, 2)
print(string, probability, '%')
# Out:
# The probability of rolling an even number or greater than 7 is: 62.3 %

# %% [markdown]
# ### Exercise 2
#
# A box contains 10 white balls, 20 reds and 30 greens. Draw 5 balls with replacement. What is the probability that:
#
# a. 3 white or 2 red
#
# b. All 5 are the same color
#
#
# We will use the same system here. We will pick our balls during each round and count the number of times that:
#
# a. 3 white or 2 red
#
# b. All 5 are the same color.

# %%
#import libraries
import numpy as np
import pandas as pd

d = {}

for i in range(60):
    if i < 10:
        d[i] = 'White'
    elif i > 9 and i < 30:
        d[i] = 'Red'
    else:
        d[i] = 'Green'  
  
        
#Initialize important variables

n_simulations=1000
probability_a = 0
probability_b = 0

for i in range(n_simulations):
    #make a list of the colors that we choose
    #Convert it to a numpy array
    list_bolls = np.array([d[np.random.randint(60)] for x in range(5)])
   
    #find the number of each taht we picked
    
    white = sum(list_bolls == 'White')
    red = sum(list_bolls  == 'Red')
    green = sum(list_bolls  == 'Green')
     
    #Keep track if the combination met the criteria
    
    if white == 3 and red == 2:
        probability_a += 1
    
    if red == 5 or white == 5 or green ==5:
        probability_b +=1
    
    
percentage_a = round(probability_a/n_simulations*100,2)
percentage_b = round(probability_b/n_simulations*100,2)
#print 'the probability of 3 white and 2 red is' in percentage
print('the probability of 3 white and 2 red is:', percentage_a, "%")
#print 'the probability of all the same color is' in percentage   
print('the probability of all the same color is:', percentage_b, "%")
# Out:
# the probability of 3 white and 2 red is: 0.8 %
# the probability of all the same color is: 4.6 %
